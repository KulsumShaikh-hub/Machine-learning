# %% [markdown]
# <a href="https://colab.research.google.com/github/KulsumShaikh-hub/Machine-learning/blob/main/Analyzer1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/adult.data.csv')
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
race_count = df['race'].value_counts()
race_count
# Out:
# race
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64

# %%
average_age_men = round(df[df['sex'] ==  ' Male' ]['age'].mean(), 1)
average_age_men
# Out:
# np.float64(39.4)

# %%
edu_bach_perc = round((df['education']== ' Bachelors').mean()* 100 ,1)
edu_bach_perc
# Out:
# np.float64(16.4)

# %%
high_edu  = df[df['education'].isin ([' Bachelors' , ' Masters' , ' Doctorate'])]
high_edu
# Out:
#        age          workclass  fnlwgt   education  education-num  \
# 0       39          State-gov   77516   Bachelors             13
# 1       50   Self-emp-not-inc   83311   Bachelors             13
# 4       28            Private  338409   Bachelors             13
# 5       37            Private  284582     Masters             14
# 8       31            Private   45781     Masters             14
# ...    ...                ...     ...         ...            ...
# 32538   38            Private  139180   Bachelors             13
# 32539   71                  ?  287372   Doctorate             16
# 32544   31            Private  199655     Masters             14
# 32553   32            Private  116138     Masters             14
# 32554   53            Private  321865     Masters             14
#
#             marital-status        occupation    relationship  \
# 0            Never-married      Adm-clerical   Not-in-family
# ...

# %%
lower_edu  = df[~df['education'].isin ([' Bachelors' , ' Masters' , ' Doctorate'])]
lower_edu
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 6       49            Private  160187            9th              5
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# 10      37            Private  280464   Some-college             10
# ...    ...                ...     ...            ...            ...
# 32556   27            Private  257302     Assoc-acdm             12
# 32557   40            Private  154374        HS-grad              9
# 32558   58            Private  151910        HS-grad              9
# 32559   22            Private  201490        HS-grad              9
# 32560   52       Self-emp-inc  287927        HS-grad              9
#
#                marital-status          occupation    relationship    race  \
# 2                    Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
higher_education_rich = round((high_edu['salary'] == ' >50K').mean() * 100, 1)
lower_education_rich = round((lower_edu['salary'] == ' >50K').mean() * 100, 1)
higher_education_rich
# Out:
# np.float64(46.5)

# %%
lower_education_rich
# Out:
# np.float64(17.4)

# %%
min_hours = df ['hours-per-week'].min()
min_hours
# Out:
# 1

# %%
#What percentage of the people who work the minimum number of hours per week have a salary of more than 50K?
min_hours_sal = df[df['hours-per-week']== min_hours]
min_hours_sal_perc = round((min_hours_sal['salary']=='>50K').mean() * 100 ,1)
min_hours_sal_perc
# Out:
# np.float64(0.0)

# %%
#What country has the highest percentage of people that earn >50K and what is that percentage?
country_percentages = (df[df['salary'] == ' >50K']['native-country'].value_counts() / df['native-country'].value_counts()) * 100
highest_earning_country = country_percentages.idxmax()
highest_earning_country_percentage = round(country_percentages.max(), 1)
highest_earning_country_percentage
# Out:
# 41.9

# %%
#Identify the most popular occupation for those who earn >50K in India.
india_50k = df[(df['native-country'] == ' India') & (df['salary'] == ' >50K')]
top_IN_occupation = india_50k['occupation'].value_counts().idxmax()
top_IN_occupation
# Out:
# ' Prof-specialty'
