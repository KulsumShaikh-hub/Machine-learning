# %% [markdown]
# <a href="https://colab.research.google.com/github/KulsumShaikh-hub/Machine-learning/blob/main/Time_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/fcc-forum-pageviews.csv', parse_dates=['date'],index_col='date')
df
# Out:
#              value
# date
# 2016-05-09    1201
# 2016-05-10    2329
# 2016-05-11    1716
# 2016-05-12   10539
# 2016-05-13    6933
# ...            ...
# 2019-11-29  171584
# 2019-11-30  141161
# 2019-12-01  142918
# 2019-12-02  220144
# 2019-12-03  158549
#
# [1304 rows x 1 columns]

# %%
low = df['value'].quantile(0.025)
high = df['value'].quantile(0.975)

df = df[(df['value'] >= low) & (df['value'] <= high)]

# %%
def draw_line_plot():
  fig, ax = plt.subplots(figsize=(15,5))
  ax.plot(df.index, df['value'], color='red', linewidth=1)

  #Customizations
  ax.set_title('Daily freeCodeCamp Forum Page Views 5/2016-12/2019')
  ax.set_xlabel('Date')
  ax.set_ylabel('Page Views')

  return fig

# %%
draw_line_plot()
